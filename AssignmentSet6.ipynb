# %% [markdown]
# ## Assignment Set6

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(0, 100)
y = x * 2
z = x ** 2

# %% [markdown]
# #### Exercise 1
#     Follow along with these steps:
#     Create a figure object called fig using plt.figure()
#     Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
#     Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, y)
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_title('Title')

plt.show()

# %% [markdown]
# #### Exercise 2
#     Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and
#     [0.2,0.5,.2,.2] respectively.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Data

x = np.arange(0.0, 1.0)
y = x * 2

# Create figure
fig = plt.figure()

# Add axes
ax1 = fig.add_axes([0, 0, 1, 1])        # Main axis
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2]) # Smaller inset axis

# Plot on both axes
ax1.plot(x, y)
ax2.plot(x, y)

# Show figure
plt.show()

# %% [markdown]
# #### Now plot (x,y) on both axes. And call your figure object to show it.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Data

x = np.arange(0, 100)
y = x * 2

# Create figure
fig = plt.figure()

# Add axes
ax1 = fig.add_axes([0, 0, 1, 1])        # Main axis
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2]) # Smaller inset axis

# Plot on both axes
ax1.plot(x, y)
ax2.plot(x, y)


# Labels for outer plot
ax1.set_xlabel('X Axis')
ax1.set_ylabel('Y Axis')
ax1.set_title('Outer Plot')

# Labels for inner plot
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Inner Plot')

# Show figure
plt.show()

# %% [markdown]
# #### Exercise 3
# Create the plot below by adding two axes to a figure object at [0,0,1,1] and
# [0.2,0.5,.4,.4]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Data
x = np.arange(0, 100)
y = x * 2
z = x ** 2

# Create figure
fig = plt.figure()

# Add axes
ax1 = fig.add_axes([0, 0, 1, 1])          # Main axis
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])  # Inset axis


# Main plot (x vs z)
ax1.plot(x, z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')
ax1.set_title('Main Plot')

# Inset plot (x vs y)
ax2.plot(x, y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Zoomed Plot')

# Set limits for zoom effect
ax2.set_xlim(20, 40)
ax2.set_ylim(30, 120)

plt.show()

# %% [markdown]
# #### Exercise 4
# Use plt.subplots(nrows=1, ncols=2) to create the plot below.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)



plt.show()

# %%
ig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)
axes[0].set_title('X vs Y')

axes[1].plot(x, z)
axes[1].set_title('X vs Z')

plt.show()
