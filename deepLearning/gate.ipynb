# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
 
# Input
X = torch.tensor([[0.,0.],
                  [0.,1.],
                  [1.,0.],
                  [1.,1.]])
 
# Change target for AND / OR / XOR
# AND
# y = torch.tensor([[0.],[0.],[0.],[1.]])
 
# OR
y = torch.tensor([[0.],[1.],[1.],[1.]])
 
# XOR
#y = torch.tensor([[0.],[1.],[1.],[0.]])
 
# Neural Network
model = nn.Sequential(
    nn.Linear(2, 4),
    nn.ReLU(),
    nn.Linear(4, 1),
    nn.Sigmoid()
)
 
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)
 
# Training
for epoch in range(5000):
    output = model(X)
    loss = criterion(output, y)
 
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
 
# Prediction
with torch.no_grad():
    print(torch.round(model(X)))
# Out:
# tensor([[0.],
#         [1.],
#         [1.],
#         [1.]])
